# %% [markdown]
# ##  準備

# %%
from pathlib import Path
from bs4 import BeautifulSoup
import json
import os
import re
import time
import shutil
import logging
import pandas as pd
# !pip install selenium
# !pip install beautiful requests
# !pip install BeautifulSoup4
from selenium import webdriver
from selenium.webdriver.support.select import Select
import requests
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from time import sleep
from selenium.common.exceptions import UnexpectedAlertPresentException
from selenium.webdriver.common.alert import Alert

pd.set_option('display.max_rows', 100)
# Out:
# Requirement already satisfied: selenium in /opt/anaconda3/lib/python3.9/site-packages (4.1.0)
# Requirement already satisfied: trio-websocket~=0.9 in /opt/anaconda3/lib/python3.9/site-packages (from selenium) (0.10.2)
# Requirement already satisfied: trio~=0.17 in /opt/anaconda3/lib/python3.9/site-packages (from selenium) (0.22.0)
# Collecting urllib3[secure]~=1.26
#   Using cached urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
# Requirement already satisfied: sortedcontainers in /opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.1.1)
# Requirement already satisfied: attrs>=19.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: async-generator>=1.9 in /opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (2.8)
# Requirement already satisfied: outcome in /opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in /opt/anaconda3/lib/python3.9/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in /opt/anaconda3/lib/python3.9/site-packages (from urllib3[secure]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in /opt/anaconda3/lib/python3.9/site-packages (from urllib3[secure]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: urllib3-secure-extra in /opt/anaconda3/lib/python3.9/site-packages (from urllib3[secure]~=1.26->selenium) (0.1.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.9/site-packages (from urllib3[secure]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.9/site-packages (from cryptography>=1.3.4->urllib3[secure]~=1.26->selenium) (1.14.6)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure]~=1.26->selenium) (2.20)
# Requirement already satisfied: six>=1.5.2 in /opt/anaconda3/lib/python3.9/site-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.16.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /opt/anaconda3/lib/python3.9/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Installing collected packages: urllib3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.25.11
#     Uninstalling urllib3-1.25.11:
#       Successfully uninstalled urllib3-1.25.11
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.1 requires ruamel-yaml, which is not installed.
# requests 2.22.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.16 which is incompatible.
# cookiecutter 1.7.2 requires requests>=2.23.0, but you have requests 2.22.0 which is incompatible.
# Successfully installed urllib3-1.26.16
# Requirement already satisfied: beautiful in /opt/anaconda3/lib/python3.9/site-packages (0.0.2)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.9/site-packages (2.22.0)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Using cached urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests) (2021.10.8)
# Installing collected packages: urllib3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.16
#     Uninstalling urllib3-1.26.16:
#       Successfully uninstalled urllib3-1.26.16
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.1 requires ruamel-yaml, which is not installed.
# selenium 4.1.0 requires urllib3[secure]~=1.26, but you have urllib3 1.25.11 which is incompatible.
# cookiecutter 1.7.2 requires requests>=2.23.0, but you have requests 2.22.0 which is incompatible.
# Successfully installed urllib3-1.25.11
# Requirement already satisfied: BeautifulSoup4 in /opt/anaconda3/lib/python3.9/site-packages (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in /opt/anaconda3/lib/python3.9/site-packages (from BeautifulSoup4) (2.2.1)

# %%
pip install chromedriver-binary-auto
# Out:
# Requirement already satisfied: chromedriver-binary-auto in /opt/anaconda3/lib/python3.9/site-packages (0.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
options = webdriver.ChromeOptions()
options.binary_location = "/Applications/Google Chrome.app/Contents/MacOS/Google Chrome"
chrome_driver_binary = "./chromedriver"
browser1 = webdriver.Chrome(chrome_driver_binary, chrome_options=options)
# Out:
# /var/folders/_q/5b0cfy_d2ks1qlbxzgflbk880000gn/T/ipykernel_11026/2148539095.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser1 = webdriver.Chrome(chrome_driver_binary, chrome_options=options)
# /var/folders/_q/5b0cfy_d2ks1qlbxzgflbk880000gn/T/ipykernel_11026/2148539095.py:4: DeprecationWarning: use options instead of chrome_options
#   browser1 = webdriver.Chrome(chrome_driver_binary, chrome_options=options)

# %%
hard_coded_colleage_list =[
    {"univ_name":"大阪工業大学","url":"https://www.portal.oit.ac.jp/CAMJWEB/slbssrch.do"},
    {"univ_name":"奈良大学","url":"https://portal.nara-u.ac.jp/portal/slbssrch.do"},
    {"univ_name":"同志社女子大学","url":"https://portal.nara-u.ac.jp/portal/slbssrch.do"},
    {"univ_name":"摂南大学","url":"https://portal.setsunan.ac.jp/CAMJWEB/slbsskgr.do?clearAccessData=true"},
    {"univ_name":"京都芸術大学","url":"https://n1.kyoto-art.ac.jp/campusweb/slbsskgr.do"},
    {"univ_name":"大阪体育大学","url":"https://syllabus.ouhs.ac.jp/campusweb/slbssrch.do"}
]
hard_coded_colleage_list =[ 
    {"univ_name":"奈良大学","url":"https://portal.nara-u.ac.jp/portal/slbssrch.do"}]

# %%
#検索結果の表示ページを切り替える
def nexe_page(browser):

    sleep(5)
    next_button = browser.find_element(By.LINK_TEXT, '次の50件>>')   

    next_button.click()


def is_next_page_exist(browser):
    next_button = browser.find_element(By.LINK_TEXT, '次の50件>>')   
    if(next_button.get_attribute("disabled") == "true"):
        print("this is the last page.")
        return False
    else:
        return True

def record_links(browser,file_name):
    tbody = browser.find_element(By.TAG_NAME, "table").find_element(By.TAG_NAME, "tbody")
    tr_elements = tbody.find_elements(By.TAG_NAME, 'tr')
    for tr_element in tr_elements:
    # <input>要素を取得します
        try:
            even_td_elements = tr_element.find_elements(By.CLASS_NAME, 'column_even')
        except:
            #ヘッダー行の回避
            continue
        try:
            odd_td_elements = tr_element.find_elements(By.CLASS_NAME, 'column_odd')
        except:
            continue
        for td_element in even_td_elements:
            try:
                key = td_element.find_element(By.TAG_NAME, 'a').get_attribute("href")
            except:
                continue
        
            print(key)
            access_url = key
            with open(file_name, 'a') as f:
               f.write(access_url+"\n")

        for td_element in odd_td_elements:
            try:
                key = td_element.find_element(By.TAG_NAME, 'a').get_attribute("href")
            except:
                continue
        
            print(key)
            access_url = key
            with open(file_name, 'a') as f:
               f.write(access_url+"\n")

# %%
def extract_jp_from_string(text):
    match = re.search(r'\.jp', text)
    if match:
        jp_index = match.start() + 3  # 「.jp」の後ろの文字のインデックス
        jp_part = text[:jp_index]  # 「.jp」までの部分を抜き出す
        return jp_part
    else:
        return None


def append_line_to_file(filename, line):
    with open(filename, 'a') as file:
        file.write(line + '\n')

for column in hard_coded_colleage_list:
    new_dir_path = column['univ_name']
    new_record_path = './'+column['univ_name']+"/"+column['univ_name']+"_links.txt"
    search_url = column['url']
    base_url = extract_jp_from_string( column['url'])
    if not os.path.exists(new_dir_path):
        os.mkdir(new_dir_path)
    if not os.path.exists(new_record_path):
        f = open(new_record_path,'w')
        f.write("")
        f.close()

    browser1.get(search_url)
    #search_button = browser1.find_element(By.NAME,'btnSearch')
    #search_button.click()

# %%
record_links(browser1,new_record_path)
while(is_next_page_exist(browser1)):
    nexe_page(browser1)
    record_links(browser1,new_record_path)
browser1.close()
# Out:
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1CBA01B0&value(crclumcd)=10201300
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1DCL17A0&value(crclumcd)=10201400
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1DCL17B0&value(crclumcd)=10201400
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1DAC03A0&value(crclumcd)=10201400
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1DAF01A0&value(crclumcd)=10201400
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1DBA01B0&value(crclumcd)=10201400
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1FCL17A0&value(crclumcd)=10201401
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1FBM11A0&value(crclumcd)=10201401
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1FBA01A0&value(crclumcd)=10201401
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1GAB01A0&value(crclumcd)=10201500
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1GAA01B0&value(crclumcd)=10201500
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=2ACA01A0&value(crclumcd)=10301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=C0C001B0&value(crclumcd)=10302ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=C0C001D0&value(crclumcd)=10302ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=C0C001F0&value(crclumcd)=10302ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=C0C001H0&value(crclumcd)=10302ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=C0C001L0&value(crclumcd)=10302ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=C1C001A0&value(crclumcd)=10303ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=C1C001C0&value(crclumcd)=10303ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=C3C001A0&value(crclumcd)=10304ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCD21M0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCD14M0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCC01A0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCC31A0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCB09A0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1CBA01A0&value(crclumcd)=10201300
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1CBD02A0&value(crclumcd)=10201300
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1DCF03B0&value(crclumcd)=10201400
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1DBM11A0&value(crclumcd)=10201400
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1DAB01A0&value(crclumcd)=10201400
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1DBA01A0&value(crclumcd)=10201400
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1DBD02A0&value(crclumcd)=10201400
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1FCL17B0&value(crclumcd)=10201401
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1FAB01A0&value(crclumcd)=10201401
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1FBA01B0&value(crclumcd)=10201401
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=1GAA01A0&value(crclumcd)=10201500
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=2ACF01A0&value(crclumcd)=10301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=C0C001A0&value(crclumcd)=10302ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=C0C001C0&value(crclumcd)=10302ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=C0C001E0&value(crclumcd)=10302ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=C0C001G0&value(crclumcd)=10302ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=C0C001I0&value(crclumcd)=10302ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=C0C001M0&value(crclumcd)=10302ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=C1C001B0&value(crclumcd)=10303ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=C1C001D0&value(crclumcd)=10303ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=C3C001C0&value(crclumcd)=10304ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCD40M0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCD33M0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCC01M0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCC31M0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCA06M0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCD17M0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCA01A0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCA20A0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCC23M0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCA33M0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=13CA22A0&value(crclumcd)=10101400
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=16CD01A0&value(crclumcd)=10101800
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=16BH01A0&value(crclumcd)=10101800
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=16BG08B0&value(crclumcd)=10101800
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A2C001A0&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A2C001C0&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A2C001F0&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A2C001H0&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A0C001G0&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A0C001J0&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A1C001A1&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A1C001B0&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A1C001B2&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A1C001C0&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A1C001C2&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A1C001D0&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A1C001D2&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A1C001F1&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A1C001G0&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCB09M0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCA26M0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCD37M0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCA01M0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCA20M0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCC33M0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=MPCA14M0&value(crclumcd)=20301100
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A4D0201A&value(crclumcd)=10104ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=16CA14A0&value(crclumcd)=10101800
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=16CB01A0&value(crclumcd)=10101800
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A2C0011A&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A2C001B0&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A2C001D0&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A2C001G0&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A0C001B0&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A0C001H0&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A1C001A0&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A1C001A2&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A1C001B1&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A1C001B3&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A1C001C1&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A1C001C3&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A1C001D1&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A1C001F0&value(crclumcd)=10102ZZZ
# https://www.portal.oit.ac.jp/CAMJWEB/slbssbdr.do?value(risyunen)=2023&value(semekikn)=1&value(kougicd)=A1C001F2&value(crclumcd)=10102ZZZ
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# /var/folders/_q/5b0cfy_d2ks1qlbxzgflbk880000gn/T/ipykernel_90964/1760782960.py in <module>
#       1 record_links(browser1,new_record_path)
# ----> 2 while(is_next_page_exist(browser1)):
#       3     nexe_page(browser1)
#       4     record_links(browser1,new_record_path)
#       5 browser1.close()
#
# /var/folders/_q/5b0cfy_d2ks1qlbxzgflbk880000gn/T/ipykernel_90964/4292405664.py in is_next_page_exist(browser)
#       9
#      10 def is_next_page_exist(browser):
# ---> 11     next_button = browser.find_element(By.LINK_TEXT, '次の50件>>')
#      12     if(next_button.get_attribute("disabled") == "true"):
#      13         print("this is the last page.")
#
# /opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#    1242             value = '[name="%s"]' % value
#    1243
# -> 1244         return self.execute(Command.FIND_ELEMENT, {
#    1245             'using': by,
#    1246             'value': value})['value']
#
# /opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# /opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"link text","selector":"次の50件>>"}
#   (Session info: chrome=114.0.5735.198)
# Stacktrace:
# 0   chromedriver                        0x00000001061ad598 chromedriver + 4973976
# 1   chromedriver                        0x00000001061a4913 chromedriver + 4938003
# 2   chromedriver                        0x0000000105d61cd6 chromedriver + 470230
# 3   chromedriver                        0x0000000105da52ff chromedriver + 746239
# 4   chromedriver                        0x0000000105da5591 chromedriver + 746897
# 5   chromedriver                        0x0000000105de7384 chromedriver + 1016708
# 6   chromedriver                        0x0000000105dc99ed chromedriver + 895469
# 7   chromedriver                        0x0000000105de4856 chromedriver + 1005654
# 8   chromedriver                        0x0000000105dc9793 chromedriver + 894867
# 9   chromedriver                        0x0000000105d9721f chromedriver + 688671
# 10  chromedriver                        0x0000000105d9856e chromedriver + 693614
# 11  chromedriver                        0x0000000106167bb7 chromedriver + 4688823
# 12  chromedriver                        0x000000010616ca51 chromedriver + 4708945
# 13  chromedriver                        0x000000010617340f chromedriver + 4736015
# 14  chromedriver                        0x000000010616d91a chromedriver + 4712730
# 15  chromedriver                        0x000000010614087c chromedriver + 4528252
# 16  chromedriver                        0x000000010618cf28 chromedriver + 4841256
# 17  chromedriver                        0x000000010618d0a7 chromedriver + 4841639
# 18  chromedriver                        0x000000010619e28f chromedriver + 4911759
# 19  libsystem_pthread.dylib             0x00007ff80ceab1d3 _pthread_start + 125
# 20  libsystem_pthread.dylib             0x00007ff80cea6bd3 thread_start + 15

# %%
import os
import glob
import random
import string
# カレントディレクトリのパスを取得
current_directory = os.getcwd()

# カレントディレクトリ内のフォルダを取得
folders = [f for f in os.listdir(current_directory) if os.path.isdir(os.path.join(current_directory, f))]

pattern = r'cd\)=(.*?)&value'

# フォルダの名前を表示
for folder_path in folders:
    file_paths = glob.glob(os.path.join(folder_path, "*.txt"))
    if file_paths != []:
        with open(file_paths[0], "r") as file:
            for line in file:
            # 行の処理を行うためのコードを追加
                response = requests.get(line)
                html = response.text
                match = re.search(pattern, line)
                if match:
                    extracted_text = match.group(1)
                    file_name = './' + folder_path + "/" + extracted_text + '.html'
                else:
                    file_name = './'.join(random.choices(string.ascii_letters + string.digits, k=10)) + '.html'
                if glob.glob(file_name) == []:
                    print(file_name)
                    sleep(10)
                    with open(r""+file_name, 'w', encoding='utf-8') as f:
                        f.write(html)
                else:
                    print("skip "+file_name)
# Out:
# skip 同志社女子大学/同志社女子大学_links.txt
# skip 同志社女子大学/同志社女子大学_links.txt
# skip 同志社女子大学/同志社女子大学_links.txt
# skip 同志社女子大学/同志社女子大学_links.txt
# skip 同志社女子大学/同志社女子大学_links.txt
# skip 同志社女子大学/同志社女子大学_links.txt
# skip 同志社女子大学/同志社女子大学_links.txt
# skip 同志社女子大学/同志社女子大学_links.txt
# skip 同志社女子大学/同志社女子大学_links.txt
# skip 同志社女子大学/同志社女子大学_links.txt
# skip 同志社女子大学/同志社女子大学_links.txt
# skip 同志社女子大学/同志社女子大学_links.txt
# skip 同志社女子大学/同志社女子大学_links.txt
# skip 同志社女子大学/同志社女子大学_links.txt
# skip 同志社女子大学/同志社女子大学_links.txt
# skip 同志社女子大学/同志社女子大学_links.txt
# skip 同志社女子大学/同志社女子大学_links.txt
# skip 同志社女子大学/同志社女子大学_links.txt
# skip 同志社女子大学/同志社女子大学_links.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/_q/5b0cfy_d2ks1qlbxzgflbk880000gn/T/ipykernel_90964/2270609303.py in <module>
#      18             for line in file:
#      19             # 行の処理を行うためのコードを追加
# ---> 20                 response = requests.get(line)
#      21                 html = response.text
#      22                 match = re.search(pattern, line)
#
# /opt/anaconda3/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /opt/anaconda3/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# /opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# /opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/anaconda3/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /opt/anaconda3/lib/python3.9/http/client.py in getresponse(self)
#    1369         try:
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#    1373                 self.close()
#
# /opt/anaconda3/lib/python3.9/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# /opt/anaconda3/lib/python3.9/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# /opt/anaconda3/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# /opt/anaconda3/lib/python3.9/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     311     def recv_into(self, *args, **kwargs):
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#     315             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# /opt/anaconda3/lib/python3.9/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1797             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1798         else:
# -> 1799             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1800         self._raise_ssl_error(self._ssl, result)
#    1801
#
# KeyboardInterrupt:

# %%
glob.glob("./大阪工業大学/11BC01A0.html")
# Out:
# ['./大阪工業大学/11BC01A0.html']
